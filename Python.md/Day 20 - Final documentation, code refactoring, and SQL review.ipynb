# %% [markdown]
# # EcoShop Seasonal Performance & Churn Analysis
#
# ## Project Objective
# The objective of this project is to analyze customer purchasing behavior using RFM analysis, create interactive dashboards in Power BI, and build a machine learning model to predict the probability of customers making a purchase within the next 30 days.
#
# ## Tools Used
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - SQL (MySQL)
# - Power BI
# - Git & GitHub
#
# ## Project Workflow
# 1. Data Cleaning
# 2. SQL Analysis
# 3. RFM Segmentation
# 4. Power BI Dashboard Development
# 5. Machine Learning Model Development
# 6. Model Evaluation
# 7. Model Saving
#
# ## Business Outcome
# The project helps identify high-value customers, understand customer purchasing patterns, and predict future purchase behavior to support marketing and customer retention strategies.

# %%
# Data Loading

# Feature Engineering

# Data Splitting

# Logistic Regression Model

# Model Evaluation

# Feature Importance

# Save Model

# %%
import pandas as pd

# %%
# Load customer dataset
df = pd.read_csv("customer_rfm_segmented.csv")

# %%
# Create target variable
df["Purchase30Days"] = (df["Recency"] <= 30).astype(int)

# %%
# Split data into training and testing sets

# %%
# Train Logistic Regression model

# %%
# Evaluate model performance

# %%
import pandas as pd

df = pd.read_csv("customer_rfm_segmented.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4312 entries, 0 to 4311
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  4312 non-null   float64
#  1   Recency     4312 non-null   int64
#  2   Frequency   4312 non-null   int64
#  3   Monetary    4312 non-null   float64
#  4   Segment     4312 non-null   object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 168.6+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID    0
# Recency       0
# Frequency     0
# Monetary      0
# Segment       0
# dtype: int64

# %%
df.describe()
# Out:
#          CustomerID      Recency    Frequency       Monetary
# count   4312.000000  4312.000000  4312.000000    4312.000000
# mean   15349.290353    91.171846     4.455705    2048.238233
# std     1701.200176    96.860633     8.170213    8914.481278
# min    12346.000000     1.000000     1.000000       2.950000
# 25%    13882.500000    18.000000     1.000000     307.987500
# 50%    15350.500000    53.000000     2.000000     706.020000
# 75%    16834.250000   136.000000     5.000000    1723.142500
# max    18287.000000   374.000000   205.000000  349164.350000

# %%
df["Segment"].value_counts()
# Out:
# Segment
# Champions    1462
# Lost         1435
# At Risk      1415
# Name: count, dtype: int64

# %%
print("Duplicate Customer IDs:", df["CustomerID"].duplicated().sum())
# Out:
# Duplicate Customer IDs: 0

# %%
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (4312, 5)

# %% [markdown]
# # SQL Review Validation
#
# Verified the SQL-generated RFM dataset in Python by checking:
# - Dataset structure
# - Missing values
# - Data types
# - Duplicate records
# - Summary statistics
# - Customer segment distribution
#
# The SQL outputs were successfully validated and met the project evaluation criteria.

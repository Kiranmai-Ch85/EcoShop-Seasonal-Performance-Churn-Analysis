# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sample_retail.CSV")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("sample_retail.CSV")
#
# File C:\ProgramData\anaconda\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\Documents\\EcoShop_Seasonal_Performance_Churn_Analysis\\Python'

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'cleaned_retail.csv',
#  'cleaned_retail.parquet',
#  'Day2_Data_Loading.ipynb',
#  'Day3_Data_Cleaning.ipynb',
#  'sample_retail.CSV.csv',
#  'Untitled.ipynb']

# %%
df = pd.read_csv("sample_retail.csv.csv")

# %%
df = pd.read_csv("sample_retail.csv.csv")
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
rfm = pd.read_csv("../DataSet/customer_rfm.csv.csv")
rfm.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0       12362      NaN          1    130.00
# 1       12533      NaN          1    929.92
# 2       12615      NaN          1     -5.95
# 3       12636      NaN          1    141.00
# 4       12682      NaN          1    426.30

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
rfm.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0       12362      NaN          1    130.00
# 1       12533      NaN          1    929.92
# 2       12615      NaN          1     -5.95
# 3       12636      NaN          1    141.00
# 4       12682      NaN          1    426.30

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df["Price"], bins=30)
plt.title("Unit Price Distribution")
plt.xlabel("Unit Price")
plt.ylabel("Frequency")
plt.show()

# %%
df["Quantity"].describe()
# Out:
# count    1000.000000
# mean       10.470000
# std        38.805192
# min      -240.000000
# 25%         1.000000
# 50%         4.000000
# 75%        12.000000
# max       800.000000
# Name: Quantity, dtype: float64

# %%
Q1 = df["Quantity"].quantile(0.25)
Q3 = df["Quantity"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print(lower)
print(upper)
# Out:
# -15.5
# 28.5

# %%
df_clean = df[(df["Quantity"] >= lower) & (df["Quantity"] <= upper)]

print("Original rows:", len(df))
print("Rows after removing outliers:", len(df_clean))
# Out:
# Original rows: 1000
# Rows after removing outliers: 928

# %%
df["Quantity"].describe()
# Out:
# count    1000.000000
# mean       10.470000
# std        38.805192
# min      -240.000000
# 25%         1.000000
# 50%         4.000000
# 75%        12.000000
# max       800.000000
# Name: Quantity, dtype: float64

# %%
Q1 = df["Quantity"].quantile(0.25)
Q3 = df["Quantity"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Lower Bound: -15.5
# Upper Bound: 28.5
